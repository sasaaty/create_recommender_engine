# %% [markdown]
# # Tracks Genre Classification
#
# - What does each playlist set sound like? What are their defining characteristics?
#
# - Using user-marked playlist genres as training data, can we build a model to correctly classify songs from a separate track dataset?

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Read and check values of 2 playlist sets

# %%
#set keyword
KEYWORD1='rock'

# %%
# read and process the playlist data for keyword
playlist1_df = pd.read_csv('data/'+KEYWORD1+'_playlist_data.csv')
playlist1_df.head(20)
# Out:
#                playlist_id                                      playlist_name  \
# 0   37i9dQZF1DWXRqgorJj26U                                      Rock Classics
# 1   37i9dQZF1DXcF6B6QPhFDv                                          Rock This
# 2   37i9dQZF1DX1rVvRgjX59F                                   90s Rock Anthems
# 3   37i9dQZF1DWYN0zdqzbEwl                                    Rock en Español
# 4   37i9dQZF1DX6xOPeSOGone                                          Soft Rock
# 5   37i9dQZF1DX8FwnYE6PRvL                                         Rock Party
# 6   37i9dQZF1DX1spT6G94GFC                                   80s Rock Anthems
# 7   37i9dQZF1DX68H8ZujdnN7                                     ’80s Hard Rock
# 8   37i9dQZF1DX2sUQwD7tbmL                               Feel-Good Indie Rock
# 9   37i9dQZF1DWWRktbhJiuqL                                   Pure Rock & Roll
# 10  37i9dQZF1DX49jUV2NfGku                                         Rock Solid
# 11  37i9dQZF1DXcmaoFmN75bi                                       Rock Forever
# 12  3Ho3iO0iJykgEQNbjB2sic  Classic Rock 70s 80s 90s, Rock Classics - 70s ...
# 13  37i9dQZF1DXb3m918yXHxA                                         Yacht Rock
# 14  37i9dQZF1DWWJOmJ7nRx0C                                          Rock Hard
# 15  37i9dQZF1DX1te6miphixI                                         Radio Rock
# 16  20LKsiDZd4ALrlihncFcFa                               90s Alternative Rock
# 17  37i9dQZF1DWTlgzqHpWg4m                              California Rock State
# 18  37i9dQZF1DWSDoVybeQisg                                   Psychedelic Rock
# 19  37i9dQZF1DX0rCrO4CFRfM                                      Acoustic Rock
#
#     playlist_total_tracks    owner_id owner_name  total_followers
# 0                     145     spotify    Spotify          8442915
# 1                      50     spotify    Spotify          4497159
# 2                     152     spotify    Spotify          3947353
# 3                      60     spotify    Spotify          3794503
# 4                     100     spotify    Spotify          2659070
# 5                      50     spotify    Spotify          1765840
# 6                      80     spotify    Spotify          1573530
# 7                     104     spotify    Spotify          1474511
# 8                     200     spotify    Spotify          1344026
# 9                     100     spotify    Spotify          1303428
# 10                     80     spotify    Spotify          1145901
# 11                     94     spotify    Spotify           880336
# 12                    587   juan20150  Juan20150           771185
# 13                    170     spotify    Spotify           736404
# 14                    100     spotify    Spotify           722539
# 15                     50     spotify    Spotify           714953
# 16                     92  myplay.com   Filtr US           696791
# 17                     73     spotify    Spotify           685085
# 18                     50     spotify    Spotify           673591
# 19                     64     spotify    Spotify           635541

# %%
playlist1_df.shape
# Out:
# (97, 6)

# %%
# read and process the playlist data for keyword
tracks1_df = pd.read_csv('data/'+KEYWORD1+'_playlist_tracks_data.csv')\
                .merge(pd.read_csv('data/'+KEYWORD1+'_playlist_tracks.csv')[['track_id','playlist_id','playlist_name']],\
                      on='track_id',how='left')
#make duration ms to minutes
tracks1_df['duration_mins']=tracks1_df['duration']/60000
#tag genre with keyword
tracks1_df['genre']=KEYWORD1
tracks1_df.head()
# Out:
#                  track_id                        track_name  \
# 0  0hCB0YR03f6AmQaHbwWDe8  Whole Lotta Love - 1990 Remaster
# 1  0hCB0YR03f6AmQaHbwWDe8  Whole Lotta Love - 1990 Remaster
# 2  0hCB0YR03f6AmQaHbwWDe8  Whole Lotta Love - 1990 Remaster
# 3  0hCB0YR03f6AmQaHbwWDe8  Whole Lotta Love - 1990 Remaster
# 4  0hCB0YR03f6AmQaHbwWDe8  Whole Lotta Love - 1990 Remaster
#
#                 artist_id   artist_name                album_id  duration  \
# 0  36QJpDe2go2KgaRleHCDTp  Led Zeppelin  70lQYZtypdCALtFVlQAcvx    333893
# 1  36QJpDe2go2KgaRleHCDTp  Led Zeppelin  70lQYZtypdCALtFVlQAcvx    333893
# 2  36QJpDe2go2KgaRleHCDTp  Led Zeppelin  70lQYZtypdCALtFVlQAcvx    333893
# 3  36QJpDe2go2KgaRleHCDTp  Led Zeppelin  70lQYZtypdCALtFVlQAcvx    333893
# 4  36QJpDe2go2KgaRleHCDTp  Led Zeppelin  70lQYZtypdCALtFVlQAcvx    333893
#
#   release_date  popularity  danceability  energy  ...  speechiness  \
# 0   1969-10-22          77         0.412   0.902  ...        0.405
# 1   1969-10-22          77         0.412   0.902  ...        0.405
# 2   1969-10-22          77         0.412   0.902  ...        0.405
# 3   1969-10-22          77         0.412   0.902  ...        0.405
# 4   1969-10-22          77         0.412   0.902  ...        0.405
#
#    acousticness  instrumentalness  liveness  valence  tempo  \
# 0        0.0484             0.131     0.405    0.422  89.74
# 1        0.0484             0.131     0.405    0.422  89.74
# 2        0.0484             0.131     0.405    0.422  89.74
# 3        0.0484             0.131     0.405    0.422  89.74
# 4        0.0484             0.131     0.405    0.422  89.74
#
#               playlist_id                                      playlist_name  \
# 0  37i9dQZF1DWXRqgorJj26U                                      Rock Classics
# 1  37i9dQZF1DX8FwnYE6PRvL                                         Rock Party
# 2  37i9dQZF1DWWRktbhJiuqL                                   Pure Rock & Roll
# 3  3Ho3iO0iJykgEQNbjB2sic  Classic Rock 70s 80s 90s, Rock Classics - 70s ...
# 4  3Ho3iO0iJykgEQNbjB2sic  Classic Rock 70s 80s 90s, Rock Classics - 70s ...
#
#    duration_mins genre
# 0       5.564883  rock
# 1       5.564883  rock
# 2       5.564883  rock
# 3       5.564883  rock
# 4       5.564883  rock
#
# [5 rows x 23 columns]

# %%
tracks1_df.shape
# Out:
# (2445, 23)

# %%
# How many unique tracks are in playlist set 1?
len(tracks1_df['track_id'].unique())
# Out:
# 2057

# %%
# What is the distribution of playlist set 1's total tracks?
playlist1_df['playlist_total_tracks'].hist()

# %%
len(playlist1_df[playlist1_df['playlist_total_tracks']>10])
# Out:
# 97

# %%
# What is the distribution of playlist set 1's total tracks?
playlist1_df['total_followers'].hist()

# %%
###################### set keyword
KEYWORD2='R&B'

# %%
# read and process the playlist data for keyword
playlist2_df = pd.read_csv('data/'+KEYWORD2+'_playlist_data.csv')
playlist2_df.head(20)
# Out:
#                playlist_id              playlist_name  playlist_total_tracks  \
# 0   37i9dQZF1DWYmmr74INQlb         I Love My '00s R&B                     40
# 1   37i9dQZF1DX6VDO8a6cQME         I Love My '90s R&B                     45
# 2   37i9dQZF1DX2UgsUIg75Vg                Chilled R&B                     50
# 3   37i9dQZF1DWSfMe9z89s9B            Alternative R&B                    100
# 4   37i9dQZF1DXbirtHQBuwCo            TrenChill K-R&B                     50
# 5   37i9dQZF1DX1wNY9tfWQsS               Women of R&B                     70
# 6   37i9dQZF1DX2WkIBRaChxW              R&B Right Now                     62
# 7   36scvoM0cRA50MCZGhv3wo         R&B Party Classics                    134
# 8   37i9dQZF1DXch2nNxu927l                Suprême R&B                     50
# 9   37i9dQZF1DX7J2y2eWxEnR                R&B Connect                     60
# 10  6PvLmTX0j8snmCi960Sb21              This Is R&B!🎤                     76
# 11  37i9dQZF1DX6EQe4DjJNfI                 R&B Brasil                     80
# 12  37i9dQZF1DWWWvWJNPeyJE                   Sexy R&B                     55
# 13  37i9dQZF1DX7FY5ma9162x             R&B Favourites                    100
# 14  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B                    243
# 15  37i9dQZF1DX942d1NzGgzk                     R&B UK                     60
# 16  37i9dQZF1DX6GYkg76TRV8                  R&B Feels                     67
# 17  37i9dQZF1DWXbttAJcbphz         I Love My '10s R&B                     50
# 18  3rA95eP8FhZHEV7pJga7Pz              r&b catalog 🎹                     15
# 19  37i9dQZF1DX4CB6zI8FWXS               Groovin' R&B                     60
#
#                      owner_id    owner_name  total_followers
# 0                     spotify       Spotify          3185162
# 1                     spotify       Spotify          2386512
# 2                     spotify       Spotify          2030487
# 3                     spotify       Spotify           860553
# 4                     spotify       Spotify           481097
# 5                     spotify       Spotify           346648
# 6                     spotify       Spotify           326803
# 7      sonymusicentertainment  Filtr Sweden           315866
# 8                     spotify       Spotify           269003
# 9                     spotify       Spotify           163555
# 10  yrkjs6dnap7oc1bjc33f95h1d     DjLinkYou           122690
# 11                    spotify       Spotify           119074
# 12                    spotify       Spotify           108269
# 13                    spotify       Spotify           106843
# 14                 karolrodis    karolrodis           106625
# 15                    spotify       Spotify            91468
# 16                    spotify       Spotify            91261
# 17                    spotify       Spotify            77911
# 18  n9ilxxb0orfjs1go642hkj919  wave catalog            61506
# 19                    spotify       Spotify            61452

# %%
playlist2_df.shape
# Out:
# (61, 6)

# %%
# read and process the playlist data for keyword
tracks2_df = pd.read_csv('data/'+KEYWORD2+'_playlist_tracks_data.csv')\
                .merge(pd.read_csv('data/'+KEYWORD2+'_playlist_tracks.csv')[['track_id','playlist_id','playlist_name']],\
                      on='track_id',how='left')
#make duration ms to minutes
tracks2_df['duration_mins']=tracks2_df['duration']/60000
#tag genre with keyword
tracks2_df['genre']=KEYWORD2
tracks2_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6nTcn8CybBcx0t7IaXEJ6O  Thank God I Found You (feat. Joe & Nas) - Make...
# 1  7FWuzwapuKHTEyDJIcQOw3       Stutter (feat. Mystikal) - Double Take Remix
# 2  3QE7ObGjkt1kYnhLvZPRUy                                         Go On Girl
# 3  6De63WRULDaa1fxOyLilnv                                             Stingy
# 4  08fhbfRSg7eEH0IZT7pB6a                                          That Girl
#
#                 artist_id      artist_name                album_id  duration  \
# 0  4iHNK0tOyZPYnBU7nGAgpQ     Mariah Carey  6zuCJaxmHKNKN5hMDF556U    251640
# 1  3zTOe1BtyTkwNvYZOxXktX              Joe  6zuCJaxmHKNKN5hMDF556U    213026
# 2  21E3waRsmPlU7jZsS13rcj            Ne-Yo  52q9xNv8COtSU9phlbO5sg    261426
# 3  7r8RF1tN2A4CiGEplkp1oP         Ginuwine  3t4OgAvvOzvXw8D2NHUeDR    259493
# 4  1goOx6gnQdUllLfSMsL4Rt  Marques Houston  4sAouJxcSwPIoT5dd6Qgj7    215960
#
#   release_date  popularity  danceability  energy  ...  speechiness  \
# 0   2000-04-18          55         0.608   0.760  ...       0.2420
# 1   2000-04-18          55         0.767   0.759  ...       0.1170
# 2   2007-01-01          65         0.637   0.521  ...       0.1090
# 3   2003-04-08          54         0.622   0.573  ...       0.0547
# 4   2003-10-21          53         0.683   0.552  ...       0.1080
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0129               0.0    0.3320    0.366  168.211
# 1        0.0513               0.0    0.3100    0.677   89.989
# 2        0.1550               0.0    0.0945    0.562   83.896
# 3        0.2600               0.0    0.1730    0.617  127.132
# 4        0.5480               0.0    0.2210    0.519   98.946
#
#               playlist_id       playlist_name  duration_mins genre
# 0  37i9dQZF1DWYmmr74INQlb  I Love My '00s R&B       4.194000   R&B
# 1  37i9dQZF1DWYmmr74INQlb  I Love My '00s R&B       3.550433   R&B
# 2  37i9dQZF1DWYmmr74INQlb  I Love My '00s R&B       4.357100   R&B
# 3  37i9dQZF1DWYmmr74INQlb  I Love My '00s R&B       4.324883   R&B
# 4  37i9dQZF1DWYmmr74INQlb  I Love My '00s R&B       3.599333   R&B
#
# [5 rows x 23 columns]

# %%
tracks2_df.shape
# Out:
# (1467, 23)

# %%
# How many unique tracks are in playlist 2?
len(tracks2_df['track_id'].unique())
# Out:
# 1293

# %% [markdown]
# ## 2. Compare histograms of 2 playlist sets

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    fig = plt.figure()
    ax= fig.add_subplot(111)
    
    sns.distplot(tracks1_df[col], ax=ax, label= KEYWORD1)
    sns.distplot(tracks2_df[col], ax=ax, label= KEYWORD2)
    plt.title("%s vs %s: %s " % (KEYWORD1,KEYWORD2,col))
    plt.ylabel('Frequency')
    plt.legend(frameon=False)
    plt.show()

# %% [markdown]
# >Q: What feature/s best distinguish the 2 categories from each other? Does it make sense to use this as a feature for a classification model?

# %% [markdown]
# ## 3. Feature Engineering

# %%
#get union of two playlist tracks list
tracks_df = pd.concat([tracks1_df,tracks2_df])
tracks1_df.shape, tracks2_df.shape, tracks_df.shape
# Out:
# ((2445, 23), (1467, 23), (3912, 23))

# %%
#retain only distinct tracks per keyword
tracks_df =tracks_df.drop_duplicates(subset='track_id')
tracks_df.shape
# Out:
# (3350, 23)

# %%
#Normalize loudness
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

tracks_df['loudness'] = scaler.fit_transform(tracks_df[['loudness']])
tracks_df['loudness'].describe()
# Out:
# count    3350.000000
# mean        0.686869
# std         0.134994
# min         0.000000
# 25%         0.608084
# 50%         0.707297
# 75%         0.786079
# max         1.000000
# Name: loudness, dtype: float64

# %%
#Normalize tempo
tracks_df['tempo'] =  scaler.fit_transform(tracks_df[['tempo']])
#check
tracks_df['tempo'].describe()
# Out:
# count    3350.000000
# mean        0.393988
# std         0.187679
# min         0.000000
# 25%         0.241706
# 50%         0.385717
# 75%         0.517090
# max         1.000000
# Name: tempo, dtype: float64

# %%
# map genres to numbers
tracks_df['genre_id'] = tracks_df['genre'].map({KEYWORD1:1,KEYWORD2:2})

# %% [markdown]
# ## 4. Preview possible groupings

# %% [markdown]
# >Q: Pick the 2 best distinguishing features of the 2 playlist sets and plot each row as a scatterplot/distplot colored by genre

# %%
sns.scatterplot(data=tracks_df, x='energy', y='tempo', hue='genre')

# %%
fig = plt.figure()
ax= fig.add_subplot(111)

colormaps = ['Reds','Blues']
for n,genre in enumerate([KEYWORD1,KEYWORD2]):
    df=tracks_df[tracks_df['genre']==genre]
    sns.kdeplot(df['energy'],df['tempo'], ax=ax,\
                shade=True, shade_lowest=False, alpha=0.5, cmap=colormaps[n],\
                label=genre)
    
plt.legend(frameon=False)

# %% [markdown]
# > Q: How would you interpret the resulting scatterplot/distribution?

# %% [markdown]
# ## 5. Model Tuning: KNN

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score,roc_curve, auc, confusion_matrix, classification_report

# %% [markdown]
# Select audio features to use for the model

# %%
# create feature matrix (X)
feature_cols = ['energy','tempo']
X = tracks_df[feature_cols]
y = tracks_df['genre_id']

# creating training set, test set and checking shapes 
X_train,X_test,Y_train,Y_test = train_test_split(X,y, test_size=0.2)
print("Shape of X_Train:"+str(X_train.shape))
print("Shape of y_Train:"+str(Y_train.shape))
print("Shape of X_Test:"+str(X_test.shape))
print("Shape of y_Test:"+str(Y_test.shape))
# Out:
# Shape of X_Train:(2680, 2)
# Shape of y_Train:(2680,)
# Shape of X_Test:(670, 2)
# Shape of y_Test:(670,)

# %% [markdown]
# Perform KNN using K= [1..50] and validate using k-fold k = 5

# %%
cv_scores = []

neighbors=np.arange(2,51)

for k in neighbors:
    print('Fitting for k=%d' % k)
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, Y_train, cv=5, scoring='accuracy')
    cv_scores.append(scores.mean())
# Out:
# Fitting for k=2
# Fitting for k=3
# Fitting for k=4
# Fitting for k=5
# Fitting for k=6
# Fitting for k=7
# Fitting for k=8
# Fitting for k=9
# Fitting for k=10
# Fitting for k=11
# Fitting for k=12
# Fitting for k=13
# Fitting for k=14
# Fitting for k=15
# Fitting for k=16
# Fitting for k=17
# Fitting for k=18
# Fitting for k=19
# Fitting for k=20
# Fitting for k=21
# Fitting for k=22
# Fitting for k=23
# Fitting for k=24
# Fitting for k=25
# Fitting for k=26
# Fitting for k=27
# Fitting for k=28
# Fitting for k=29
# Fitting for k=30
# Fitting for k=31
# Fitting for k=32
# Fitting for k=33
# Fitting for k=34
# Fitting for k=35
# Fitting for k=36
# Fitting for k=37
# Fitting for k=38
# Fitting for k=39
# Fitting for k=40
# Fitting for k=41
# Fitting for k=42
# Fitting for k=43
# Fitting for k=44
# Fitting for k=45
# Fitting for k=46
# Fitting for k=47
# Fitting for k=48
# Fitting for k=49
# Fitting for k=50

# %% [markdown]
# Choose optimal value of K

# %%
# changing to misclassification error
mse = [1 - x for x in cv_scores]

# determining best k
optimal_k = neighbors[mse.index(min(mse))]
print("The optimal number of neighbors is {}".format(optimal_k))

# plot misclassification error vs k
plt.plot(neighbors, mse)
plt.xlabel("Number of Neighbors K")
plt.ylabel("Misclassification Error")
plt.show()
# Out:
# The optimal number of neighbors is 25

# %% [markdown]
# Compute accuracy of optimal K for the testing set

# %%
knn_optimal = KNeighborsClassifier(n_neighbors=optimal_k)

# fitting the model
knn_optimal.fit(X_train, Y_train)

# predict the response
pred = knn_optimal.predict(X_test)

# evaluate accuracy
acc = accuracy_score(Y_test, pred) * 100
print('\nThe accuracy of the knn classifier for k = %d is %f%%' % (optimal_k, acc))
# Out:
# The accuracy of the knn classifier for k = 25 is 68.955224%

# %% [markdown]
# Create a classification report

# %%
print(classification_report(y,knn_optimal.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.75      0.77      2057
#            2       0.63      0.67      0.65      1293
#
#     accuracy                           0.72      3350
#    macro avg       0.71      0.71      0.71      3350
# weighted avg       0.73      0.72      0.72      3350

# %% [markdown]
# - accuracy = all correct /all
# - precision =  TP/TP+FP
# - recall = TP/TP+FN
# - f1-score = weighted average of Precision and Recall
#         F1 Score = 2*(Recall * Precision) / (Recall + Precision)
# - support = number of items in the class
#
# - macro ave = average of the unweighted mean per label
# - weighted ave = average of the weighted mean per label

# %% [markdown]
# Plot an ROC curve for each position type prediction using the optimal KNN model

# %%
y_scores = knn_optimal.predict_proba(X_test)
genres = tracks_df['genre'].unique()

fig = plt.figure(figsize=[8,5])

for i in np.arange(len(genres)):
    genre_id = i+1
    y_test =[1 if k==genre_id else 0 for k in Y_test]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores[:, i])
    roc_auc = auc(fpr, tpr)

    ax = fig.add_subplot('1'+str(len(genres))+str(i))
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.title('Y = '+str(genres[i]))

# %% [markdown]
# ## 6. Model Tuning: SVM

# %%
from sklearn.svm import SVC

# %%
# https://scikit-learn.org/stable/auto_examples/svm/plot_iris_svc.html#sphx-glr-auto-examples-svm-plot-iris-svc-py
def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    xmgn= (x.max()-x.min())*0.25
    ymgn = (y.max()-y.min())*0.25
    
    x_min, x_max = x.min() - xmgn, x.max() + xmgn
    y_min, y_max = y.min() - ymgn, y.max() + ymgn
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(ax, clf, xx, yy, xlims,ylims, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    ax.set_ylim(ylims)
    ax.set_xlim(xlims)
    
    return out

#visualize support vectors
def plot_vector_bounds(X,svm_model):
    fig,ax=plt.subplots()

    X0 = X.to_numpy()[:, 0]
    X1 = X.to_numpy()[:, 1]
    xx, yy = make_meshgrid(X0, X1)

    plot_contours(ax, svm_model, xx, yy, [0,1],[0,1],
                      cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y,cmap=plt.cm.coolwarm, s=20, edgecolors='k')

# %%
# create feature matrix (X)
feature_cols = ['energy','tempo']
X = tracks_df[feature_cols]
y = tracks_df['genre_id']

# creating training set, test set and checking shapes 
X_train,X_test,Y_train,Y_test = train_test_split(X,y, test_size=0.2)
print("Shape of X_Train:"+str(X_train.shape))
print("Shape of y_Train:"+str(Y_train.shape))
print("Shape of X_Test:"+str(X_test.shape))
print("Shape of y_Test:"+str(Y_test.shape))
# Out:
# Shape of X_Train:(2680, 2)
# Shape of y_Train:(2680,)
# Shape of X_Test:(670, 2)
# Shape of y_Test:(670,)

# %% [markdown]
# >Q: Go back to the scatter/distplot. What seems to be the appropriate kernel type to use for the classification?

# %% [markdown]
# Fit model and use at least 2 kernels

# %%
svm_model1 = SVC(kernel='linear')
pred1 = svm_model1.fit(X, y)

# %%
#plot bounds
plot_vector_bounds(X,svm_model1)

# %%
#show classification
print(classification_report(y,svm_model1.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.77      0.75      2057
#            2       0.60      0.55      0.58      1293
#
#     accuracy                           0.69      3350
#    macro avg       0.67      0.66      0.66      3350
# weighted avg       0.68      0.69      0.68      3350

# %%
#polynomial kernel
svm_model2 = SVC(kernel='poly', degree=3, gamma=0.9)
pred2 = svm_model2.fit(X, y)

# %%
#plot bounds
plot_vector_bounds(X,svm_model2)

# %%
#show classification
print(classification_report(y,svm_model2.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.69      0.73      2057
#            2       0.58      0.69      0.63      1293
#
#     accuracy                           0.69      3350
#    macro avg       0.68      0.69      0.68      3350
# weighted avg       0.70      0.69      0.69      3350

# %%
#polynomial kernel
svm_model3 = SVC(kernel='rbf', gamma=0.8)
pred3 = svm_model3.fit(X, y)

# %%
#plot bounds
plot_vector_bounds(X,svm_model3)

# %%
#show classification
print(classification_report(y,svm_model3.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.76      0.72      0.74      2057
#            2       0.59      0.65      0.62      1293
#
#     accuracy                           0.69      3350
#    macro avg       0.68      0.68      0.68      3350
# weighted avg       0.70      0.69      0.69      3350

# %% [markdown]
# ## 7. Model Selection

# %% [markdown]
# Which between KNN and SVM performed better?
# Create a column matching the predicted genre and probability of the better model to each of the tracks

# %%
tracks_df['predicted_genre_id'] = tracks_df.apply(lambda x:  knn_optimal.predict(x[feature_cols].values.reshape(1,-1))[0]\
                                               , axis=1)
tracks_df['predicted_genre_prob'] = tracks_df.apply(lambda x:  np.max(knn_optimal.predict_proba(x[feature_cols].values.reshape(1,-1)))\
                                                    , axis=1)
tracks_df
# Out:
#                     track_id                               track_name  \
# 0     0hCB0YR03f6AmQaHbwWDe8         Whole Lotta Love - 1990 Remaster
# 5     2aoo2jlRnM3A0NyLQqMN2f                 All Along the Watchtower
# 8     08mG3Y1vljYA6bvDt4Wqkj                            Back In Black
# 12    1RJeiAIwR9pZBgJA8ndZLL                   Paint It, Black - Mono
# 13    66lOpKgTyFjOrac4S1s94g              Rebel Rebel - 1999 Remaster
# ...                      ...                                      ...
# 1462  6a51sCiFIP84K75HXhMei3                                    Chloe
# 1463  1h49nxOoviRjy9Dyz53Gr7                                   London
# 1464  18eZc40EneLmStYEy3cLBP                                 Kamikaze
# 1465  5SMKa6EVTFltVoZlNcKMYM  Simple Things [Feat. Tory Lanez & Rema]
# 1466  7GU4sdexteLwpjIZ36QPFL                                  Circles
#
#                    artist_id         artist_name                album_id  \
# 0     36QJpDe2go2KgaRleHCDTp        Led Zeppelin  70lQYZtypdCALtFVlQAcvx
# 5     776Uo845nYHJpNaStv1Ds4        Jimi Hendrix  5z090LQztiqh13wYspQvKQ
# 8     711MCceyCBcFnzjGY4Q7Un               AC/DC  6mUdeDZCsExyJLMdAfDuwh
# 12    22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones  5nKpMsduwp5xqCKq2IbSKv
# 13    0oSGxfWSnnOXhD2fKuz2Gy         David Bowie  6JxxRxzjsOTtKVie29FTt2
# ...                      ...                 ...                     ...
# 1462  7ItuVBUh0amgt1MCDkshWx                NUMB  0F2toa93tEbYKI7z5TnUw7
# 1463  0f2YkMXwFNJNSX7MymevKE         Kaash Paige  0nfhJM8ywsCnOmoJNblItu
# 1464  5FxD8fkQZ6KcsSYupDVoSO         Omar Apollo  6LXh08HxqIquqWttoIHInn
# 1465  0orEyXhG0KnPEDVgpctNJI                DJDS  42epDPc7PKuwg4Z0ddv6KE
# 1466  2iojnBLj0qIMiKPvVhLnsH          Trey Songz  65tz6yI9G9USj9R7jh1qh5
#
#       duration release_date  popularity  danceability  energy  ...  liveness  \
# 0       333893   1969-10-22          77         0.412   0.902  ...    0.4050
# 5       240800   1968-10-25          78         0.438   0.805  ...    0.0842
# 8       255493   1980-07-25          84         0.310   0.700  ...    0.0828
# 12      204480   1966-01-01          69         0.505   0.836  ...    0.2950
# 13      269360   1974-04-24           0         0.676   0.920  ...    0.2480
# ...        ...          ...         ...           ...     ...  ...       ...
# 1462    163732   2020-08-21          33         0.642   0.752  ...    0.0823
# 1463    167840   2020-08-14          56         0.654   0.521  ...    0.0684
# 1464    210914   2020-09-10          63         0.705   0.734  ...    0.0930
# 1465    214406   2020-07-09          52         0.641   0.623  ...    0.2050
# 1466    257385   2020-08-14          65         0.681   0.651  ...    0.1030
#
#       valence     tempo             playlist_id  playlist_name  duration_mins  \
# 0       0.422  0.192516  37i9dQZF1DWXRqgorJj26U  Rock Classics       5.564883
# 5       0.564  0.344666  37i9dQZF1DWXRqgorJj26U  Rock Classics       4.013333
# 8       0.763  0.830844  37i9dQZF1DWXRqgorJj26U  Rock Classics       4.258217
# 12      0.764  0.645019  37i9dQZF1DWXRqgorJj26U  Rock Classics       3.408000
# 13      0.624  0.429357  37i9dQZF1DWXRqgorJj26U  Rock Classics       4.489333
# ...       ...       ...                     ...            ...            ...
# 1462    0.608  0.194198  37i9dQZF1DX4CB6zI8FWXS   Groovin' R&B       2.728867
# 1463    0.223  0.148798  37i9dQZF1DX4CB6zI8FWXS   Groovin' R&B       2.797333
# 1464    0.457  0.226527  37i9dQZF1DX4CB6zI8FWXS   Groovin' R&B       3.515233
# 1465    0.398  0.287327  37i9dQZF1DX4CB6zI8FWXS   Groovin' R&B       3.573433
# 1466    0.416  0.298024  37i9dQZF1DX4CB6zI8FWXS   Groovin' R&B       4.289750
#
#       genre  genre_id  predicted_genre_id predicted_genre_prob
# 0      rock         1                   1                 0.92
# 5      rock         1                   1                 0.76
# 8      rock         1                   1                 0.68
# 12     rock         1                   1                 0.96
# 13     rock         1                   1                 0.96
# ...     ...       ...                 ...                  ...
# 1462    R&B         2                   2                 0.60
# 1463    R&B         2                   2                 0.68
# 1464    R&B         2                   2                 0.60
# 1465    R&B         2                   2                 0.64
# 1466    R&B         2                   2                 0.60
#
# [3350 rows x 26 columns]

# %% [markdown]
# Check tracks mistakenly classified with but high probability

# %%
tracks_df[(tracks_df['predicted_genre_id']!=tracks_df['genre_id'])&(tracks_df['predicted_genre_prob']>0.9)]
# Out:
#                     track_id  \
# 11    7f1Dmr246cJ9uQYdbplTbh
# 38    3VEZvzr84WVnoorZ4tlBSw
# 65    40xz60ciGIpsRtDqRfPKBE
# 171   3sPxWL4msAoJXdyUQGrblt
# 280   7LBuBVWzbvpirsmmnpw9qc
# 316   086tVFodHOXOSN4xM0KDTE
# 394   5lAH3vLN4Gc3jDM25cMIgH
# 453   7beY8mXJuC4l0J2WgVoCfm
# 495   0CmQgwV3Bmzh9nZb9TNVEI
# 548   1uXbwHHfgsXcUKfSZw5ZJ0
# 551   53d2PwHmwGBuV2UD69oPT2
# 552   26JdVMSr2FfmuUF9ZWl6bq
# 563   4jnFqNWeJCeCRHc4HCdxfd
# 565   4WimB4Ei0LU3MotHhL3kBL
# 567   4a8e7TuFTFFtCyDAFb4JCD
# 573   4INDiWSKvqSKDEu7mh8HFz
# 604   7qtAgn9mwxygsPOsUDVRRt
# 658   1FKxKGONukVFXWVJxAKmlz
# 666   1mnqraQ8oV8MX92rdOFLWW
# 673   0JmGVy7IzUM27My3UuEOOZ
# 692   1GxHeBvQ9935Dd3cSfsfBa
# 709   58AGoOGbwsQMhBbH0eFLRR
# 806   4lpqCn6j8LO5MT1hO1XNxs
# 808   6E2i3SCph0o36JVTTDqFXr
# 836   5gH8sa8AEKpZJLy91E2uyt
# 1085  46zP8t1PBok0Qlml3G4uW0
# 1155  5Y77SQxEr1eiofPeUTPHxM
# 1173  6h559JisvdngvCs0QUE1yw
# 1182  0Kqm6ILdnk7oyoV9k2vW1m
# 1230  58FUwmyGUqkt53YPUcm7cJ
# 1235  6Ap8lYgDbcDOPr9TAXfcnm
# 1249  1DmLlPEKT79nAXC8J1mXfC
# 1254  3SfZpKjMwvUQKGCty1dJ0T
# 1256  4o4ABOcQEZcS8V8BnNL9jv
# 1458  485KVYPmRISdLpKbaSJ81u
#
#                                              track_name  \
# 11                                 He Wasn't Man Enough
# 38                                      He Can't Love U
# 65                                Rub You The Right Way
# 171                                     God Is A Genius
# 280                                             One Day
# 316                                   Bad (feat. WOODZ)
# 394                                          Square Biz
# 453                                          Bad Habits
# 495                                            Do To Me
# 548                               Run the World (Girls)
# 551                                             1 Thing
# 552                          My Boo - Hitman's Club Mix
# 563                                   Remember the Time
# 565   Ooh Wee (feat. Ghostface Killah, Nate Dogg, Tr...
# 567                                He Wasn't Man Enough
# 573   Mo Money Mo Problems (feat. Puff Daddy & Mase)...
# 604                                            Survivor
# 658                                        Sweet Dreams
# 666                                             1 Thing
# 673                                      Knock You Down
# 692                                     Best I Ever Had
# 709                          Over Now (with The Weeknd)
# 806                                                 You
# 808                                             Forrest
# 836                                               Bored
# 1085                              Warming up - Club Mix
# 1155                                                You
# 1173                                         Lights Out
# 1182                                             Single
# 1230                                     Knock You Down
# 1235                                                You
# 1249                                             Heaven
# 1254                            Slow Down - 12" Version
# 1256                                    Before Daybreak
# 1458     Oops (I'm Sorry) (feat. Ty Dolla $ign & GASHI)
#
#                    artist_id           artist_name                album_id  \
# 11    3X458ddYA2YcVWuVIGGOYe          Toni Braxton  0UZsKcXzOehMvFWTiBlwMi
# 38    7Aq8lpLMSt1Zxu56pe9bmp           Jagged Edge  4tIkdOt2ohTHJ1VptEwNu3
# 65    7oHzn7edwmrYClrPRINkbn           Johnny Gill  3VNcHyjMgpq2UQN5LTs4qC
# 171   5ae3MM8dgOn3QPHzqFDJlY            Kevin Ross  7BFxdEOrbFdMGGXjCI7iVO
# 280   6E9Q3EKPiOPUbBBFU1YXzi        Chris Anderson  2OtUwcHivk5SAq5W8hNrcC
# 316   0gRsw676mIkWWAT1zdAHXb                  Kriz  1NUclkDY8OCyYtTvRN9avI
# 394   61UT1Zj9dFgPAjZfwnsqsb           Teena Marie  7rBP3Z4FX95gFPTXgs4MMo
# 453   23zg3TcAtWQy7J6upgbUnj                 Usher  2sD4s8plx7sdr7Qn580kK6
# 495   3Y7RZ31TRPVadSFVy1o8os                H.E.R.  6b9SrV7fOCmUubzvBQvRVg
# 548   6vWDO969PvNqNYHIOW5v0m               Beyoncé  1gIC63gC3B7o7FfpPACZQJ
# 551   08rMCq2ek1YjdDBsCPVH2s                Amerie  1uK1d6H0smXhjc13Osgoj1
# 552   4JbmXqez7WvTggoxn3UpVT        Ghost Town DJs  1uK1d6H0smXhjc13Osgoj1
# 563   3fMbdgg4jU18AjLCKBhRSm       Michael Jackson  0oX4SealMgNXrvRDhqqOKg
# 565   3hv9jJF3adDNsBSIQDqcjp           Mark Ronson  62Qu5QoNx3De0p5qQT0u7o
# 567   3X458ddYA2YcVWuVIGGOYe          Toni Braxton  44YkbOX8QxlFuBtYec4hPG
# 573   5me0Irg2ANcsgc93uaYrpb  The Notorious B.I.G.  7dRdaGSxgcBdJnrOviQRuB
# 604   1Y8cdNmUJH7yBTd9yOvr5i       Destiny's Child  0IVseR3zfrrInlKJQNh294
# 658   6vWDO969PvNqNYHIOW5v0m               Beyoncé  23Y5wdyP5byMFktZf8AcWU
# 666   08rMCq2ek1YjdDBsCPVH2s                Amerie  2PFK4dMZkqUQfxfSrK8WMf
# 673   63wjoROpeh5f11Qm93UiJ1           Keri Hilson  4ujRfwvBeflZJ7tzzA0XBJ
# 692   3TVXtAsR1Inumwj472S9r4                 Drake  6agmeioaDOBupymziJihgB
# 709   7CajNmpbOovFoOoasH2HaY         Calvin Harris  3GPiefSRSOxqTrgKJIB7RL
# 806   5FRr69AUVoFMQPcdk2LT5P                 Mosaé  6ln8QRxiaBoVcmwgeo2EDV
# 808   3Hlp36Bu8aso9nJ8FYyuEe                Shacar  7CEvcpAGNLbZqMNRE1F0hb
# 836   2hBFjgFv69Ofd9cv8JuHxN                 Rayne  1zTbpJyl9lYvxRdOkz5kwX
# 1085  42XFUQSO1X5rOvd35Yhv9h           DJ Galactic  57MwGJ1aRMPYtk95SscPQV
# 1155  1Xfmvd48oOhEWkscWyEbh9                 Lloyd  6Lq7nLkIq7C0zVJp0OGSGO
# 1173  0z6j3MncRCFuW77JhhPx8b               Meresha  7uksHZONZae2wLAfhtT0Uw
# 1182  21E3waRsmPlU7jZsS13rcj                 Ne-Yo  1nv3KEXZPmcwOXMoLTs1vn
# 1230  63wjoROpeh5f11Qm93UiJ1           Keri Hilson  4FdIO8yB9bNtcWlRcStXvZ
# 1235  1Xfmvd48oOhEWkscWyEbh9                 Lloyd  142vTN9svotwu8bxaOULNb
# 1249  2mMZuj5Zd5vB9ey7SEGxSL           Shawn Smith  07tig0SFpkXXQyUQFAZ9CV
# 1254  4HgF4KnohByNElYid7iCNb              Bobby V.  5D7khI4iB1RseZNgoBQPLi
# 1256  3j93Mm5NCkwT2dh0ELcXRf               Dj Armz  50ePtvo1zTvG9QekZPwOnS
# 1458  3hyEbRtp617pNCuuQjyOmc            Lost Kings  1ElsjvR5Stcl155XkRzJwK
#
#       duration release_date  popularity  danceability  energy  ...  liveness  \
# 11      261933         2000          67         0.739   0.947  ...    0.3260
# 38      244053   2000-01-18          58         0.721   0.836  ...    0.2350
# 65      332306   1990-01-01          50         0.660   0.873  ...    0.3310
# 171     203313   2020-05-29          53         0.550   0.875  ...    0.1840
# 280     322870   2020-06-23          34         0.374   0.888  ...    0.1090
# 316     194373   2018-09-21          32         0.709   0.881  ...    0.1100
# 394     385573   2001-01-01           1         0.767   0.925  ...    0.4090
# 453     257249   2020-09-10          71         0.620   0.829  ...    0.1110
# 495     225103   2020-07-08          69         0.477   0.854  ...    0.1680
# 548     236093   2011-06-24          73         0.733   0.899  ...    0.3720
# 551     239733   2018-04-06           0         0.617   0.962  ...    0.0268
# 552     347400   2018-04-06           0         0.818   0.799  ...    0.0177
# 563     239226   1991-11-13          69         0.831   0.921  ...    0.3050
# 565     209626   2003-08-29          53         0.727   0.961  ...    0.3340
# 567     262093   2007-02-12          49         0.737   0.927  ...    0.3840
# 573     257399   1997-03-04          73         0.845   0.884  ...    0.2030
# 604     253933   2001-01-01          65         0.524   0.904  ...    0.7760
# 658     208066   2008-11-14          61         0.694   0.825  ...    0.0618
# 666     238760         2005          61         0.612   0.961  ...    0.0413
# 673     326186   2009-01-01          65         0.588   0.877  ...    0.1710
# 692     258760   2010-01-01          63         0.431   0.894  ...    0.1880
# 709     210795   2020-08-28          85         0.612   0.884  ...    0.2470
# 806     254117   2020-08-20          33         0.610   0.870  ...    0.1490
# 808     198530   2020-08-13           0         0.359   0.788  ...    0.1260
# 836     171630   2020-06-19          42         0.723   0.812  ...    0.1680
# 1085    363779   2020-01-29          13         0.722   0.815  ...    0.0940
# 1155    273133   2007-01-01          70         0.412   0.876  ...    0.2970
# 1173    178909   2017-10-06          28         0.346   0.848  ...    0.1030
# 1182    257933   2008-01-01           0         0.701   0.908  ...    0.1080
# 1230    326186   2009-01-01          65         0.588   0.877  ...    0.1710
# 1235    273133   2007-01-01           0         0.412   0.876  ...    0.2970
# 1249    215760   2018-10-12          19         0.519   0.955  ...    0.1300
# 1254    258666   2005-01-01           0         0.563   0.746  ...    0.3380
# 1256    160442   2018-12-20          31         0.711   0.867  ...    0.1220
# 1458    202486   2020-10-02          65         0.657   0.797  ...    0.1170
#
#       valence     tempo             playlist_id              playlist_name  \
# 11      0.763  0.181315  37i9dQZF1DWYmmr74INQlb         I Love My '00s R&B
# 38      0.508  0.428956  37i9dQZF1DWYmmr74INQlb         I Love My '00s R&B
# 65      0.864  0.335730  37i9dQZF1DX6VDO8a6cQME         I Love My '90s R&B
# 171     0.539  0.177620  37i9dQZF1DX2UgsUIg75Vg                Chilled R&B
# 280     0.457  0.180079  37i9dQZF1DWSfMe9z89s9B            Alternative R&B
# 316     0.648  0.420033  37i9dQZF1DXbirtHQBuwCo            TrenChill K-R&B
# 394     0.732  0.347358  37i9dQZF1DX1wNY9tfWQsS               Women of R&B
# 453     0.636  0.597199  37i9dQZF1DX2WkIBRaChxW              R&B Right Now
# 495     0.494  0.549069  37i9dQZF1DX2WkIBRaChxW              R&B Right Now
# 548     0.760  0.434178  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 551     0.845  0.458541  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 552     0.687  0.407809  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 563     0.794  0.310687  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 565     0.800  0.291462  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 567     0.745  0.181347  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 573     0.904  0.288259  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 604     0.655  0.654849  36scvoM0cRA50MCZGhv3wo         R&B Party Classics
# 658     0.788  0.400937  37i9dQZF1DXch2nNxu927l                Suprême R&B
# 666     0.867  0.452212  37i9dQZF1DXch2nNxu927l                Suprême R&B
# 673     0.645  0.615874  37i9dQZF1DXch2nNxu927l                Suprême R&B
# 692     0.605  0.661145  37i9dQZF1DXch2nNxu927l                Suprême R&B
# 709     0.679  0.763916  37i9dQZF1DX7J2y2eWxEnR                R&B Connect
# 806     0.576  0.711922  6PvLmTX0j8snmCi960Sb21              This Is R&B!🎤
# 808     0.624  0.853001  6PvLmTX0j8snmCi960Sb21              This Is R&B!🎤
# 836     0.503  0.465898  6PvLmTX0j8snmCi960Sb21              This Is R&B!🎤
# 1085    0.310  0.433596  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1155    0.703  0.454063  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1173    0.364  0.489679  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1182    0.236  0.479041  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1230    0.645  0.615874  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1235    0.703  0.454063  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1249    0.625  0.676151  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1254    0.598  0.816168  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1256    0.363  0.304197  7rIUjHHI7hlbpXG7VSqfg5  Old School RnB, 2000s R&B
# 1458    0.327  0.556743  37i9dQZF1DX4CB6zI8FWXS               Groovin' R&B
#
#       duration_mins  genre  genre_id  predicted_genre_id predicted_genre_prob
# 11         4.365550    R&B         2                   1                 0.96
# 38         4.067550    R&B         2                   1                 0.92
# 65         5.538433    R&B         2                   1                 0.92
# 171        3.388550    R&B         2                   1                 0.92
# 280        5.381167    R&B         2                   1                 0.92
# 316        3.239550    R&B         2                   1                 0.96
# 394        6.426217    R&B         2                   1                 1.00
# 453        4.287483    R&B         2                   1                 0.96
# 495        3.751717    R&B         2                   1                 0.96
# 548        3.934883    R&B         2                   1                 0.96
# 551        3.995550    R&B         2                   1                 0.92
# 552        5.790000    R&B         2                   1                 0.92
# 563        3.987100    R&B         2                   1                 0.96
# 565        3.493767    R&B         2                   1                 0.96
# 567        4.368217    R&B         2                   1                 0.92
# 573        4.289983    R&B         2                   1                 0.92
# 604        4.232217    R&B         2                   1                 0.92
# 658        3.467767    R&B         2                   1                 0.92
# 666        3.979333    R&B         2                   1                 0.92
# 673        5.436433    R&B         2                   1                 0.96
# 692        4.312667    R&B         2                   1                 0.92
# 709        3.513250    R&B         2                   1                 0.96
# 806        4.235283    R&B         2                   1                 1.00
# 808        3.308833    R&B         2                   1                 0.92
# 836        2.860500    R&B         2                   1                 0.92
# 1085       6.062983    R&B         2                   1                 0.92
# 1155       4.552217    R&B         2                   1                 0.92
# 1173       2.981817    R&B         2                   1                 1.00
# 1182       4.298883    R&B         2                   1                 0.96
# 1230       5.436433    R&B         2                   1                 0.96
# 1235       4.552217    R&B         2                   1                 0.92
# 1249       3.596000    R&B         2                   1                 1.00
# 1254       4.311100    R&B         2                   1                 0.92
# 1256       2.674033    R&B         2                   1                 0.92
# 1458       3.374767    R&B         2                   1                 0.96
#
# [35 rows x 26 columns]

# %% [markdown]
# > Q: Focus on any of the songs you know that made it in the misclassified list (you may listen to some of them)
#     Does it make sense that the model misclassfied this song? Why or why not?

# %% [markdown]
# >Q: Would this model correctly classify tracks from the Spotify charting tracks dataset?

# %%
chart_tracks_df = pd.read_csv("data/spotify_daily_charts_tracks.csv")
chart_tracks_df.head()
# Out:
#                  track_id                  track_name               artist_id  \
# 0  0ofbQMrRDsUaVKq2mGLEAb                      Havana  4nDoRrQiYLoBzwC5BhVJzF
# 1  0tgVpDi06FyKpA1z0VMD4v                     Perfect  6eUKZXaKkcviH0Ku9w2n3V
# 2  3hBBKuWJfxlIlnd9QFoC8k  What Lovers Do (feat. SZA)  04gDigrS5kc9YWfZHwBETP
# 3  1mXVgsBdtIVeCLJnSnmtdV        Too Good At Goodbyes  2wY79sveU1sp5g7SokKOiI
# 4  2ekn2ttSfGqwhhate0LSR0                   New Rules  6M2wZ9GZgrQXHCFfjv46we
#
#       artist_name                album_id  duration release_date  popularity  \
# 0  Camila Cabello  5chBPOVY2I0bG5V3igb5QL    216896   2017-08-03           5
# 1      Ed Sheeran  3T4tUhGYeRNVUGevb0wThu    263400   2017-03-03          86
# 2        Maroon 5  1Jmq5HEJeA9kNi2SgQul4U    199849   2017-11-03           5
# 3       Sam Smith  3TJz2UBNYJtlEly0sPeNrQ    201000   2017-11-03          81
# 4        Dua Lipa  01sfgrNbnnPUEyz6GZYlt9    209320   2017-06-02          81
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.768   0.517    7    -4.323     0       0.0312       0.18600
# 1         0.599   0.448    8    -6.312     1       0.0232       0.16300
# 2         0.795   0.615    5    -5.211     0       0.0671       0.07860
# 3         0.681   0.372    5    -8.237     1       0.0432       0.64000
# 4         0.762   0.700    9    -6.021     0       0.0694       0.00261
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000038    0.1040    0.418  104.992
# 1          0.000000    0.1060    0.168   95.050
# 2          0.000003    0.0855    0.393  110.009
# 3          0.000000    0.1690    0.476   91.873
# 4          0.000016    0.1530    0.608  116.073

# %%
chart_tracks_df['predicted_genre_id'] = chart_tracks_df.apply(lambda x:  knn_optimal.predict(x[feature_cols].values.reshape(1,-1))[0]\
                                               , axis=1)
chart_tracks_df['predicted_genre_prob'] = chart_tracks_df.apply(lambda x:  np.max(knn_optimal.predict_proba(x[feature_cols].values.reshape(1,-1)))\
                                                    , axis=1)
chart_tracks_df.head()
# Out:
#                  track_id                  track_name               artist_id  \
# 0  0ofbQMrRDsUaVKq2mGLEAb                      Havana  4nDoRrQiYLoBzwC5BhVJzF
# 1  0tgVpDi06FyKpA1z0VMD4v                     Perfect  6eUKZXaKkcviH0Ku9w2n3V
# 2  3hBBKuWJfxlIlnd9QFoC8k  What Lovers Do (feat. SZA)  04gDigrS5kc9YWfZHwBETP
# 3  1mXVgsBdtIVeCLJnSnmtdV        Too Good At Goodbyes  2wY79sveU1sp5g7SokKOiI
# 4  2ekn2ttSfGqwhhate0LSR0                   New Rules  6M2wZ9GZgrQXHCFfjv46we
#
#       artist_name                album_id  duration release_date  popularity  \
# 0  Camila Cabello  5chBPOVY2I0bG5V3igb5QL    216896   2017-08-03           5
# 1      Ed Sheeran  3T4tUhGYeRNVUGevb0wThu    263400   2017-03-03          86
# 2        Maroon 5  1Jmq5HEJeA9kNi2SgQul4U    199849   2017-11-03           5
# 3       Sam Smith  3TJz2UBNYJtlEly0sPeNrQ    201000   2017-11-03          81
# 4        Dua Lipa  01sfgrNbnnPUEyz6GZYlt9    209320   2017-06-02          81
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.768   0.517  ...    -4.323     0       0.0312       0.18600
# 1         0.599   0.448  ...    -6.312     1       0.0232       0.16300
# 2         0.795   0.615  ...    -5.211     0       0.0671       0.07860
# 3         0.681   0.372  ...    -8.237     1       0.0432       0.64000
# 4         0.762   0.700  ...    -6.021     0       0.0694       0.00261
#
#    instrumentalness  liveness  valence    tempo  predicted_genre_id  \
# 0          0.000038    0.1040    0.418  104.992                   1
# 1          0.000000    0.1060    0.168   95.050                   1
# 2          0.000003    0.0855    0.393  110.009                   1
# 3          0.000000    0.1690    0.476   91.873                   1
# 4          0.000016    0.1530    0.608  116.073                   1
#
#    predicted_genre_prob
# 0                  0.56
# 1                  0.56
# 2                  0.56
# 3                  0.56
# 4                  0.60
#
# [5 rows x 21 columns]

# %%
#Check tracks classified with higher probability
chart_tracks_df.sort_values(['predicted_genre_prob'])[:10]
# Out:
#                     track_id                    track_name  \
# 0     0ofbQMrRDsUaVKq2mGLEAb                        Havana
# 1286  43zdsphuZLzwA9k4DJhU0I         when the party's over
# 1285  4SSnFejRGlZikf02HLewEF                 bury a friend
# 1284  3Fj47GNK2kUF0uaEDgXLaD             wish you were gay
# 1283  2Fxmhks0bxGSBdJ92vM42m                       bad guy
# 1282  4u7EnebtmKWzUH433cf5Qv  Bohemian Rhapsody - 2011 Mix
# 1280  3u9tIlAnygQGNJ5VuSvTfi                    Bagay Tayo
# 1278  2rXVtoLBHuXcNB5DVfIc9p                     Happiness
# 1275  59aZ0ioyVrmtdut1KfU5aT                         Amatz
# 1274  2H4gf1wLxvYreMj1jcaN0k                    Be Alright
#
#                    artist_id        artist_name                album_id  \
# 0     4nDoRrQiYLoBzwC5BhVJzF     Camila Cabello  5chBPOVY2I0bG5V3igb5QL
# 1286  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish  0S0KGZnfBGSIssfF54WSJh
# 1285  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish  0S0KGZnfBGSIssfF54WSJh
# 1284  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish  0S0KGZnfBGSIssfF54WSJh
# 1283  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish  0S0KGZnfBGSIssfF54WSJh
# 1282  1dfeR4HaWDbWqFHLkxsg1d              Queen  1GbtB4zTqAsyfZEsm1RZfx
# 1280  0WleeEe3UurwlNbDGhb5Yz            ALLMO$T  7EyFdHaGHh73lOZz1zuFTe
# 1278  7pbDxGE6nQSZVfiFdq9lOL  Rex Orange County  2NBVxjZcbH5H1N1Ab2ExDH
# 1275  6ogIjp0fsbUxlqy9q2rvrT        Shanti Dope  6uydeIIBbr8sN6XdI3rpuy
# 1274  3QSQFmccmX81fWCUSPTS7y         Dean Lewis  1mRtVjwGgBvLiaJhPGHZ8M
#
#       duration release_date  popularity  danceability  energy  ...  loudness  \
# 0       216896   2017-08-03           5         0.768   0.517  ...    -4.323
# 1286    196077   2019-03-29          86         0.367   0.111  ...   -14.084
# 1285    193143   2019-03-29          81         0.905   0.389  ...   -14.505
# 1284    221543   2019-03-29          80         0.853   0.351  ...   -10.198
# 1283    194087   2019-03-29          89         0.701   0.425  ...   -10.965
# 1282    354320   1975-11-21          83         0.414   0.404  ...    -9.928
# 1280    397033   2018-12-04           0         0.804   0.557  ...    -8.658
# 1278    279693   2017-04-26          71         0.399   0.235  ...    -9.774
# 1275    234374   2019-03-22          52         0.825   0.496  ...    -8.562
# 1274    196493   2019-03-22           0         0.551   0.537  ...    -7.595
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0       0.0312       0.18600          0.000038    0.1040    0.418
# 1286     1       0.0972       0.97800          0.000040    0.0897    0.198
# 1285     1       0.3320       0.74000          0.162000    0.1060    0.196
# 1284     1       0.2410       0.39000          0.000009    0.7520    0.282
# 1283     1       0.3750       0.32800          0.130000    0.1000    0.562
# 1282     0       0.0499       0.27100          0.000000    0.3000    0.224
# 1280     1       0.1630       0.32200          0.000000    0.1060    0.645
# 1278     1       0.0334       0.73400          0.000002    0.1610    0.197
# 1275     1       0.0503       0.00817          0.000511    0.0827    0.185
# 1274     1       0.0340       0.70500          0.000000    0.0802    0.493
#
#         tempo  predicted_genre_id  predicted_genre_prob
# 0     104.992                   1                  0.56
# 1286   82.642                   1                  0.56
# 1285  120.046                   1                  0.56
# 1284  118.028                   1                  0.56
# 1283  135.128                   1                  0.56
# 1282   71.105                   1                  0.56
# 1280  100.053                   1                  0.56
# 1278  105.645                   1                  0.56
# 1275  127.987                   1                  0.56
# 1274  126.421                   1                  0.56
#
# [10 rows x 21 columns]

# %%
#View histogram of probabilities
chart_tracks_df['predicted_genre_prob'].hist()

# %% [markdown]
# ## Day Deliverable
# 1. *Genre Classification (Individual)*
#
#     A. Choose up to 6 music genres and obtain track data from the genre's top 20 most-followed playlists in Spotify. A group may distribute the data gathering task by assigning a genre to each person and then pooling all the gathered data in one shared folder.
#
#    B. Pick any 2 music genres as your groupings for the classification exercise and repeat Steps 1-7. Make sure to answer the guide questions for each step
#
#    C. Increase the number of features included in the models and repeat Steps 1-7 (but skip the plotting code cells). How does this affect the model scores?
#
#    D. Modify the notebook to take in any 3 music genres as groupings and repeat Steps 1-7.
#
#
# 2. *(Optional, but useful to do ahead for your sprint project)*
#
#     There are almost [innumerable](https://www.musicgenreslist.com/) named music genres online, but a summarized list  may be found [here](https://www.blisshq.com/music-library-management-blog/2011/01/25/fundamental-music-genre-list/). Can you build a model that can predict **at least 5 genres** listed in the latter with **>70% classification accuracy**?
#
#
# 3. *(Truly optional)*
#
#     Can you build a **decision-tree**-based genre classification model with a >70% classification accuracy?
